# %%
import pandas as pd

# %% [markdown]
# # Import data into pandas

# %%
event_codes = pd.read_csv("prompt/Event_Codes.txt", delimiter='\t')
game_lineup = pd.read_csv("prompt/Game_Lineup.txt", delimiter='\t')
play_by_play = pd.read_csv("prompt/Play_by_Play.txt", delimiter='\t')

# %%
event_codes.head()
# Out:
#    Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0               1            0  Made Shot
# 1               1            1  Made Shot
# 2               1            2  Made Shot
# 3               1            3  Made Shot
# 4               1            4  Made Shot
#
#   Action_Type_Description
# 0                 No Shot
# 1               Jump Shot
# 2       Running Jump Shot
# 3               Hook Shot
# 4                Tip Shot

# %%
game_lineup.head()
# Out:
#                             Game_id  Period                         Person_id  \
# 0  006728e4c10e957011e1f24878e6054a       0  ae53f8ba6761b64a174051da817785bc
# 1  006728e4c10e957011e1f24878e6054a       0  44230324724c84f122ac62a5f0918314
# 2  006728e4c10e957011e1f24878e6054a       0  8d2127290c94bd41b82a2938734bc750
# 3  006728e4c10e957011e1f24878e6054a       0  48ec4e6c52f418d5ca4ef510ba473ea0
# 4  006728e4c10e957011e1f24878e6054a       0  e816ff284dc3f965b8f3d605a3b91bae
#
#                             Team_id status
# 0  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 1  45ba8fc87f55b1191c50c400dc7ed11c      A
# 2  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 3  45ba8fc87f55b1191c50c400dc7ed11c      A
# 4  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A

# %%
play_by_play.head()
# Out:
#                             Game_id  Event_Num  Event_Msg_Type  Period  \
# 0  a466c76e072fd634f6d4a8938fb63caa          2              12       1
# 1  a466c76e072fd634f6d4a8938fb63caa          4              10       1
# 2  d36de5306a05d0cdbd51a7294ac91359          2              12       1
# 3  d522ea3836b8e1977ab10b3bfeb5dfd1          2              12       1
# 4  d522ea3836b8e1977ab10b3bfeb5dfd1          4              10       1
#
#    WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 0   330350     7200            0        0        0        0
# 1   330350     7200            0        0        0        0
# 2   330550     7200            0        0        0        0
# 3   330550     7200            0        0        0        0
# 4   330550     7200            0        0        0        0
#
#                             Team_id                           Person1  \
# 0  1473d70e5646a26de3c52aa1abd85b1f  0370a0d090da0d0edc6319f120187e0e
# 1  0a6fc39f34702cff144525dfd265f8fa  b265ffd84dbeef427136d140811e7d5f
# 2  1473d70e5646a26de3c52aa1abd85b1f  0370a0d090da0d0edc6319f120187e0e
# 3  1473d70e5646a26de3c52aa1abd85b1f  0370a0d090da0d0edc6319f120187e0e
# 4  8362dfecb7412f12a12713852d2ae566  ef8b068ab7ac9d387b256404acd24cd5
#
#                             Person2                           Person3  \
# 0  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1  90115ca1e9f545b291b18a7db8d2a700  95c8abc40fb4ecf4fa5627975450dc95
# 2  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 3  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 4  64e4b07f8d90902bcab1aa9e6b5d2ecf  95920e4bf5b6c15ba8dffbf959b38ba5
#
#    Team_id_type  Person1_type  Person2_type  Person3_type
# 0             0             0             0             0
# 1             2             4             5             4
# 2             0             0             0             0
# 3             0             0             0             0
# 4             2             4             5             4

# %% [markdown]
# # Brief Overlook of the Data

# %%
# number of games we need to process
play_by_play['Game_id'].unique().shape[0]
# Out:
# 82

# %%
play_by_play[play_by_play['Event_Msg_Type'] == 20]
# Out:
#                                 Game_id  Event_Num  Event_Msg_Type  Period  \
# 63     006728e4c10e957011e1f24878e6054a         84              20       1
# 190    006728e4c10e957011e1f24878e6054a        256              20       2
# 211    006728e4c10e957011e1f24878e6054a        282              20       2
# 257    006728e4c10e957011e1f24878e6054a        345              20       3
# 291    006728e4c10e957011e1f24878e6054a        391              20       3
# 336    006728e4c10e957011e1f24878e6054a        449              20       4
# 346    006728e4c10e957011e1f24878e6054a        463              20       4
# 348    006728e4c10e957011e1f24878e6054a        465              20       4
# 671    03ac65b9a32fde1e201bfb427f6e41e4        337              20       3
# 713    03ac65b9a32fde1e201bfb427f6e41e4        401              20       3
# 753    03ac65b9a32fde1e201bfb427f6e41e4        447              20       3
# 827    03ac65b9a32fde1e201bfb427f6e41e4        565              20       4
# 912    03ac65b9a32fde1e201bfb427f6e41e4        691              20       4
# 925    096e231adad0be6ab1cc89cce56847f8         11              20       1
# 995    096e231adad0be6ab1cc89cce56847f8        111              20       1
# 1138   096e231adad0be6ab1cc89cce56847f8        321              20       2
# 1152   096e231adad0be6ab1cc89cce56847f8        341              20       3
# 1204   096e231adad0be6ab1cc89cce56847f8        409              20       3
# 1267   096e231adad0be6ab1cc89cce56847f8        500              20       4
# 1268   096e231adad0be6ab1cc89cce56847f8        501              20       4
# 1300   096e231adad0be6ab1cc89cce56847f8        542              20       4
# 1308   096e231adad0be6ab1cc89cce56847f8        553              20       4
# 1453   117a5a71c34c2d8a39ff66d884462bd7        130              20       1
# 1520   117a5a71c34c2d8a39ff66d884462bd7        224              20       2
# 1747   117a5a71c34c2d8a39ff66d884462bd7        568              20       4
# 1825   117a5a71c34c2d8a39ff66d884462bd7        694              20       4
# 1881   1ea0a33aafb4a3cb31ba79cff049300c         41              20       1
# 1893   1ea0a33aafb4a3cb31ba79cff049300c         54              20       1
# 1996   1ea0a33aafb4a3cb31ba79cff049300c        203              20       2
# 2044   1ea0a33aafb4a3cb31ba79cff049300c        275              20       2
# ...                                 ...        ...             ...     ...
# 35834  ed95a454eee025e4b93e217ad6a578f1        372              20       3
# 35838  ed95a454eee025e4b93e217ad6a578f1        377              20       3
# 35848  ed95a454eee025e4b93e217ad6a578f1        391              20       3
# 35868  ed95a454eee025e4b93e217ad6a578f1        416              20       3
# 36019  efca551b622ff96393fb43947e1aad4b         13              20       1
# 36070  efca551b622ff96393fb43947e1aad4b         82              20       1
# 36134  efca551b622ff96393fb43947e1aad4b        172              20       2
# 36188  efca551b622ff96393fb43947e1aad4b        247              20       2
# 36251  efca551b622ff96393fb43947e1aad4b        332              20       3
# 36270  efca551b622ff96393fb43947e1aad4b        361              20       3
# 36373  efca551b622ff96393fb43947e1aad4b        503              20       4
# 36455  f280a671f82eb32b48f00116b8956445         35              20       1
# 36494  f280a671f82eb32b48f00116b8956445         90              20       1
# 36532  f280a671f82eb32b48f00116b8956445        148              20       1
# 36605  f280a671f82eb32b48f00116b8956445        252              20       2
# 36638  f280a671f82eb32b48f00116b8956445        302              20       2
# 36678  f280a671f82eb32b48f00116b8956445        359              20       2
# 36703  f280a671f82eb32b48f00116b8956445        405              20       3
# 36713  f280a671f82eb32b48f00116b8956445        420              20       3
# 36903  f280a671f82eb32b48f00116b8956445        700              20       4
# 36926  f280a671f82eb32b48f00116b8956445        735              20       4
# 37045  f959bc122b1ee996f3e12bc61c068ad4        150              20       1
# 37366  f959bc122b1ee996f3e12bc61c068ad4        609              20       4
# 37501  ff42c1cba89fd3f3a7a6711a11d5576d        143              20       1
# 37531  ff42c1cba89fd3f3a7a6711a11d5576d        183              20       2
# 37538  ff42c1cba89fd3f3a7a6711a11d5576d        191              20       2
# 37551  ff42c1cba89fd3f3a7a6711a11d5576d        208              20       2
# 37742  ff42c1cba89fd3f3a7a6711a11d5576d        494              20       3
# 37838  ff42c1cba89fd3f3a7a6711a11d5576d        621              20       4
# 37854  ff42c1cba89fd3f3a7a6711a11d5576d        642              20       4
#
#        WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 63      554800     3000            3        0        0        0
# 190     576970     1730            3        0        0        0
# 211     579790      235            3        0        0        0
# 257     597610     4120            3        0        0        0
# 291     600880     1950            3        0        0        0
# 336     610340     6560            3        0        0        0
# 346     611810     5980            4        0        0        0
# 348     612050     5850            3        0        0        0
# 671     716920     6980            3        0        0        0
# 713     723250     4060            3        0        0        0
# 753     729020     2330            3        0        0        0
# 827     746010     5460            3        0        0        0
# 912     760720      166            3        0        0        0
# 925     583220     6500            3        0        0        0
# 995     597190     1520            3        0        0        0
# 1138    621190        8            3        0        0        0
# 1152    632420     6210            3        0        0        0
# 1204    645890     2480            3        0        0        0
# 1267    657030     5590            3        0        0        0
# 1268    657160     5590            4        0        0        0
# 1300    663180     3810            3        0        0        0
# 1308    664030     3410            3        0        0        0
# 1453    596210     1550            3        0        0        0
# 1520    608850     5080            3        0        0        0
# 1747    654370     5230            3        0        0        0
# 1825    668970     1410            3        0        0        0
# 1881    677520     5320            3        0        0        0
# 1893    678900     4460            3        0        0        0
# 1996    693390     4370            3        0        0        0
# 2044    698200     1770            3        0        0        0
# ...        ...      ...          ...      ...      ...      ...
# 35834   604860     3580            3        0        0        0
# 35838   605640     3420            3        0        0        0
# 35848   607580     2850            1        0        0        0
# 35868   610440     2080            3        0        0        0
# 36019   583760     6760            3        0        0        0
# 36070   591880     2820            5        0        0        0
# 36134   602880     5400            3        0        0        0
# 36188   611810     1330            3        0        0        0
# 36251   634760     4700            3        0        0        0
# 36270   637740     3300            3        0        0        0
# 36373   653990     3780            3        0        0        0
# 36455   549630     5550            3        0        0        0
# 36494   556340     3540            3        0        0        0
# 36532   563910     1050            3        0        0        0
# 36605   577460     4710            4        0        0        0
# 36638   583150     3000            3        0        0        0
# 36678   589730     1360            3        0        0        0
# 36703   602200     6960            3        0        0        0
# 36713   605320     6480            3        0        0        0
# 36903   637940     1400            3        0        0        0
# 36926   641280      111            3        0        0        0
# 37045   628260     1130            5        0        0        0
# 37366   693820     1850            3        0        0        0
# 37501   527610     1310            3        0        0        0
# 37531   532500     6750            3        0        0        0
# 37538   533380     6270            3        0        0        0
# 37551   534840     5460            3        0        0        0
# 37742   575290     1060            3        0        0        0
# 37838   595270     2100            3        0        0        0
# 37854   597130     1060            3        0        0        0
#
#                                 Team_id                           Person1  \
# 63     01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 190    01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 211    01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 257    45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 291    01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 336    45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 346    01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 348    45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 671    b5464c11e1a8a18452a7d2988badfe0c  0370a0d090da0d0edc6319f120187e0e
# 713    cd45058739ed0ac8229849c6249aad48  0370a0d090da0d0edc6319f120187e0e
# 753    b5464c11e1a8a18452a7d2988badfe0c  0370a0d090da0d0edc6319f120187e0e
# 827    cd45058739ed0ac8229849c6249aad48  0370a0d090da0d0edc6319f120187e0e
# 912    cd45058739ed0ac8229849c6249aad48  0370a0d090da0d0edc6319f120187e0e
# 925    45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 995    01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 1138   45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 1152   45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 1204   45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 1267   01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 1268   01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 1300   01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 1308   45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 1453   5df2526720f9ac092e202de922f5a65f  0370a0d090da0d0edc6319f120187e0e
# 1520   e2d25dd55740327314a2a0b874621ba8  0370a0d090da0d0edc6319f120187e0e
# 1747   5df2526720f9ac092e202de922f5a65f  0370a0d090da0d0edc6319f120187e0e
# 1825   5df2526720f9ac092e202de922f5a65f  0370a0d090da0d0edc6319f120187e0e
# 1881   b5464c11e1a8a18452a7d2988badfe0c  0370a0d090da0d0edc6319f120187e0e
# 1893   b5464c11e1a8a18452a7d2988badfe0c  0370a0d090da0d0edc6319f120187e0e
# 1996   b5464c11e1a8a18452a7d2988badfe0c  0370a0d090da0d0edc6319f120187e0e
# 2044   91ea9fc14670a54b9902eb062b416ccf  0370a0d090da0d0edc6319f120187e0e
# ...                                 ...                               ...
# 35834  8362dfecb7412f12a12713852d2ae566  0370a0d090da0d0edc6319f120187e0e
# 35838  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 35848  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 35868  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 36019  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 36070  8362dfecb7412f12a12713852d2ae566  0370a0d090da0d0edc6319f120187e0e
# 36134  8362dfecb7412f12a12713852d2ae566  0370a0d090da0d0edc6319f120187e0e
# 36188  8362dfecb7412f12a12713852d2ae566  0370a0d090da0d0edc6319f120187e0e
# 36251  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 36270  8362dfecb7412f12a12713852d2ae566  0370a0d090da0d0edc6319f120187e0e
# 36373  cc5e0f4efd0f5410547d4e73f38f7811  0370a0d090da0d0edc6319f120187e0e
# 36455  012059d397c0b7e5a30a5bb89c0b075e  0370a0d090da0d0edc6319f120187e0e
# 36494  dc0f916810cb46c22beec67a860e00b4  0370a0d090da0d0edc6319f120187e0e
# 36532  012059d397c0b7e5a30a5bb89c0b075e  0370a0d090da0d0edc6319f120187e0e
# 36605  012059d397c0b7e5a30a5bb89c0b075e  0370a0d090da0d0edc6319f120187e0e
# 36638  012059d397c0b7e5a30a5bb89c0b075e  0370a0d090da0d0edc6319f120187e0e
# 36678  dc0f916810cb46c22beec67a860e00b4  0370a0d090da0d0edc6319f120187e0e
# 36703  012059d397c0b7e5a30a5bb89c0b075e  0370a0d090da0d0edc6319f120187e0e
# 36713  dc0f916810cb46c22beec67a860e00b4  0370a0d090da0d0edc6319f120187e0e
# 36903  dc0f916810cb46c22beec67a860e00b4  0370a0d090da0d0edc6319f120187e0e
# 36926  dc0f916810cb46c22beec67a860e00b4  0370a0d090da0d0edc6319f120187e0e
# 37045  cd45058739ed0ac8229849c6249aad48  0370a0d090da0d0edc6319f120187e0e
# 37366  5df2526720f9ac092e202de922f5a65f  0370a0d090da0d0edc6319f120187e0e
# 37501  01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 37531  45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 37538  01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 37551  01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 37742  45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
# 37838  01be0ad4af7aeb1f6d2cc2b6b6d6d811  0370a0d090da0d0edc6319f120187e0e
# 37854  45ba8fc87f55b1191c50c400dc7ed11c  0370a0d090da0d0edc6319f120187e0e
#
#                                 Person2                           Person3  \
# 63     0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 190    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 211    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 257    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 291    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 336    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 346    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 348    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 671    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 713    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 753    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 827    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 912    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 925    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 995    0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1138   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1152   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1204   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1267   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1268   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1300   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1308   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1453   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1520   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1747   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1825   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1881   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1893   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1996   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 2044   0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# ...                                 ...                               ...
# 35834  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 35838  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 35848  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 35868  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36019  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36070  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36134  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36188  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36251  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36270  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36373  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36455  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36494  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36532  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36605  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36638  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36678  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36703  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36713  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36903  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 36926  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37045  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37366  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37501  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37531  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37538  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37551  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37742  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37838  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 37854  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 63                2             0             0             0
# 190               2             0             0             0
# 211               2             0             0             0
# 257               3             0             0             0
# 291               2             0             0             0
# 336               3             0             0             0
# 346               2             0             0             0
# 348               3             0             0             0
# 671               3             0             0             0
# 713               2             0             0             0
# 753               3             0             0             0
# 827               2             0             0             0
# 912               2             0             0             0
# 925               3             0             0             0
# 995               2             0             0             0
# 1138              3             0             0             0
# 1152              3             0             0             0
# 1204              3             0             0             0
# 1267              2             0             0             0
# 1268              2             0             0             0
# 1300              2             0             0             0
# 1308              3             0             0             0
# 1453              2             0             0             0
# 1520              3             0             0             0
# 1747              2             0             0             0
# 1825              2             0             0             0
# 1881              3             0             0             0
# 1893              3             0             0             0
# 1996              3             0             0             0
# 2044              2             0             0             0
# ...             ...           ...           ...           ...
# 35834             2             0             0             0
# 35838             3             0             0             0
# 35848             3             0             0             0
# 35868             3             0             0             0
# 36019             2             0             0             0
# 36070             3             0             0             0
# 36134             3             0             0             0
# 36188             3             0             0             0
# 36251             2             0             0             0
# 36270             3             0             0             0
# 36373             2             0             0             0
# 36455             3             0             0             0
# 36494             2             0             0             0
# 36532             3             0             0             0
# 36605             3             0             0             0
# 36638             3             0             0             0
# 36678             2             0             0             0
# 36703             3             0             0             0
# 36713             2             0             0             0
# 36903             2             0             0             0
# 36926             2             0             0             0
# 37045             3             0             0             0
# 37366             2             0             0             0
# 37501             2             0             0             0
# 37531             3             0             0             0
# 37538             2             0             0             0
# 37551             2             0             0             0
# 37742             3             0             0             0
# 37838             2             0             0             0
# 37854             3             0             0             0
#
# [452 rows x 18 columns]

# %%
play_by_play.sort_values(by=['Period','PC_Time','WC_Time','Event_Num'], ascending=[True,False,True,True], inplace=True)
play_by_play.reset_index(inplace=True, drop=True)

# %%
play_by_play[(play_by_play['Event_Msg_Type'] == 6) & (play_by_play['Action_Type'] == 14)]
# play_by_play.iloc[746-5:746+5,:]
# Out:
#                                 Game_id  Event_Num  Event_Msg_Type  Period  \
# 746    03ac65b9a32fde1e201bfb427f6e41e4        437               6       3
# 1154   096e231adad0be6ab1cc89cce56847f8        344               6       3
# 3841   2877e9e9980619126420db0163ee0779        304               6       2
# 7196   403719b7c2a6208e817387e06ffefb77        587               6       4
# 8080   476e6303a0d6728a5848a179a119bb32        562               6       4
# 10750  62083f5d100803b41537d7afa1de25b3        476               6       4
# 24136  b6badbf582ad7c8e52c35cb5308e3ffb        353               6       3
# 25436  bb4e1b593cc210dec5fdcb0f7eb4739d        278               6       2
# 31530  d508da19217d10b9a4566ef06184b4fd        465               6       4
# 33805  e08f26c110e19f7afa4cbe5aed43be4a        260               6       2
# 37447  ff42c1cba89fd3f3a7a6711a11d5576d         68               6       1
#
#        WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 746     727180     2530           14        0        0        2
# 1154    632700     6110           14        0        0        2
# 3841    610470     1400           14        0        0        2
# 7196    760020     2670           14        0        0        2
# 8080    677270     2290           14        1        0        2
# 10750   615140     5010           14        0        0        2
# 24136   594980     5730           14        0        0        2
# 25436   508440     1240           14        0        0        2
# 31530   557970     6020           14        0        0        2
# 33805   574740     2920           14        0        0        1
# 37447   517570     4290           14        0        0        2
#
#                                 Team_id                           Person1  \
# 746    cd45058739ed0ac8229849c6249aad48  41c0674725d4cddab004649e9db5a3ce
# 1154   01be0ad4af7aeb1f6d2cc2b6b6d6d811  48ec4e6c52f418d5ca4ef510ba473ea0
# 3841   e2d25dd55740327314a2a0b874621ba8  16d76c912992709c8be29b896b8f9417
# 7196   bcdf0d0117f2e3d5afcd70f977eae3d6  a1591595c04d12e88e3cb427fb667618
# 8080   0a6fc39f34702cff144525dfd265f8fa  7f438c18058290903c46dfe9d71bd68a
# 10750  8362dfecb7412f12a12713852d2ae566  137eed94de2c9698e4ac04e9ae73df02
# 24136  0a6fc39f34702cff144525dfd265f8fa  8ef226e011978823e53492a28d71217f
# 25436  b5464c11e1a8a18452a7d2988badfe0c  2c447ab0a100cb50766552b0f6fadc2d
# 31530  45ba8fc87f55b1191c50c400dc7ed11c  f4a5ca938177c407a9dab5412e39498f
# 33805  45ba8fc87f55b1191c50c400dc7ed11c  ae53f8ba6761b64a174051da817785bc
# 37447  01be0ad4af7aeb1f6d2cc2b6b6d6d811  99104de2626f67c1fa2ce70504970c3f
#
#                                 Person2                           Person3  \
# 746    ff59dc439c6c323320bc355afe884fcb  aa3b80d27f18c221408b698c7d89d250
# 1154   c5dd5b2e3b975f0849d9b74e74125cb9  4c28632a1ac678cf75a2110234adbf29
# 3841   f85a47779c423d73ea3b2aa48c54ff8b  24b95770922cd7772df8e5250e86a702
# 7196   d63f6d3cb837e14523a89546ff649ed7  6095bcbf4e6a692492b2d9f0a3b975a8
# 8080   95c8abc40fb4ecf4fa5627975450dc95  81efe876f336ab00d7331d21e9ac06dd
# 10750  fb64ca4b8beaf4c4c6e4575fe2f3abd7  6095bcbf4e6a692492b2d9f0a3b975a8
# 24136  3007e387a7d41a704390cb5878271b9a  e6316849fc94da16ecfd25fa67cf8c17
# 25436  6ad10958a1d4920dccb1daec39bebd6b  5201a0c1055bebf092c5ce178e5c7863
# 31530  48ec4e6c52f418d5ca4ef510ba473ea0  8b8d9227a96ad6ed93838617e3a2319a
# 33805  616281dee946056b071699476fdee9ec  81efe876f336ab00d7331d21e9ac06dd
# 37447  766802a8fda500d7945950de7398c9c6  07d9e91acd630847d464ab580db967e7
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 746               2             5             4             1
# 1154              2             5             4             1
# 3841              2             5             4             1
# 7196              3             4             5             1
# 8080              2             5             4             1
# 10750             2             5             4             1
# 24136             2             5             4             1
# 25436             2             5             4             1
# 31530             2             5             4             1
# 33805             2             5             4             1
# 37447             2             5             4             1

# %% [markdown]
# # Information

# %% [markdown]
# ### Event_msg_type documentation:
#     1   -->   Made Shot              (add points, possession ends & changes)
#     2   -->   Missed Shot            (don't add points, don't change possession --> DONT CARE)
#     3   -->   Free Throw             (add points, possession remain same)
#     4   -->   Rebound                (possesion could change, remain same)
#     5   -->   Turnover               (possession changes)
#     6   -->   Foul                   (don't add points, don't change possession) (what about offensive foul though?? does a turnover event follow?)
#     7   -->   Violation              (what about offensive violation though?? does a turnover event follow?)
#     8   -->   Substitution           (change active players)
#     9   -->   Timeout                (DONT CARE)
#     10  -->   Jumpball               (gotta figure out possession after jumpball)
#     11  -->   Ejection               (DONT CARE)
#     12  -->   Start Period
#     13  -->   End Period             (possession ends)
#     14  -->   Validation             (DIDNT EXIST)
#     15  -->   Memo                   (DIDNT EXIST)
#     16  -->   Final Box Printed      (DONT CARE)
#     18  -->   Instant Replay         (DONT CARE)
#     20  -->   Stoppage               (DONT CARE)
#
#
# ### Final Deliverable
#     """
#     +-------------+---------------+------------+------------+
#     |   Game_ID   |   Player_ID   |   OffRtg   |   DefRtg   |
#     +-------------+---------------+------------+------------+
#     """

# %% [markdown]
# # Define Classes

# %%
class Game():
    """
    Records all the information of one game
    """
    def __init__(self, game_id, df_play_by_play, df_game_lineup):
        self.game_id = game_id
        self.df_play_by_play = df_play_by_play.copy()
        self.df_game_lineup = df_game_lineup.copy()
        
        # get the 2 teams of this game
        self.team_A_id, self.team_B_id = self.df_game_lineup['Team_id'].unique().tolist()
        
        # get the players of the 2 teams
        self.team_A_players = self.df_game_lineup[self.df_game_lineup['Team_id'] == self.team_A_id]['Person_id'].unique().tolist()
        self.team_B_players = self.df_game_lineup[self.df_game_lineup['Team_id'] == self.team_B_id]['Person_id'].unique().tolist()
        
        # create 2 Team objects
        self.team_A = Team(self.game_id, self.team_A_id, self.team_A_players)
        self.team_B = Team(self.game_id, self.team_B_id, self.team_B_players)
        
        # sort the play_by_play data
        self.df_play_by_play.sort_values(by=['Period','PC_Time','WC_Time','Event_Num'], ascending=[True,False,True,True], inplace=True)
    
    def __str__(self):
        ret = "Game ID:\t{}\n".format(self.game_id)
        ret += "\n\tTeam A ID:\t{}\n".format(self.team_A_id)
        ret += "\tTeam B ID:\t{}\n\n".format(self.team_B_id)
        return ret
    
    def check_team(player_id):
        if player_id in self.team_A_players:
            return self.team_A_id
        if player_id in self.team_B_players:
            return self.team_B_id
    
    def process_one_row(self):
        """
        Processes one row of play_by_play data
        """
        
        pass
    
    def points_scored(self):
        pass
    
    def possession_ends(self):
        pass
    
    def free_throw(self):
        pass
    
    def substitution(self):
        pass

# %%
# records all the information of one team in one game
class Team():
    def __init__(self, game_id, team_id, player_ids_list = []):
        self.game_id = game_id
        self.team_id = team_id
        
        # player_ids mapped to corresponding Player object
        self.roster = {}
        for player_id in player_ids_list:
            self.roster[player_id] = Player(self.game_id, self.team_id, player_id)
        
        # need 2 active lists to keep track of active players during fouls/free throws
        self.active_1 = []
        self.active_2 = []
        
    
    def __str__(self):
        ret = "Team ID:\t{}\n\n".format(self.team_id)
        for idx, player_id in enumerate(self.roster):
            ret += "\tPlayer {}:\t{}\n".format(idx+1, player_id)
        
        return ret
        
    
    def get_player(self, player_id):
        return self.roster[player_id]

# %%
class Player():
    def __init__(self, game_id, team_id, player_id):
        self.game_id = game_id
        self.team_id = team_id
        self.player_id = player_id
    
        self.points_scored = 0
        self.points_allowed = 0
        self.off_possessions = 0
        self.def_possessions = 0
    
    def __str__(self):
        ret = "Player ID: {}\n".format(self.player_id)
        ret += "\tPoints Scored: {}\n".format(self.points_scored)
        ret += "\tPoints Allowed: {}\n".format(self.points_allowed)
        ret += "\tPossessions: {}\n".format(self.possessions)
        ret += "\tOffensive Rating: {}\n".format(self.get_offensive_rating())
        ret += "\tDefensive Rating: {}\n".format(self.get_defensive_rating())
        
        return ret
    
    def add_points_scored(self, points):
        self.points_scored += points
        
    def add_points_allowed(self, points):
        self.points_allowed += points
    
    def add_off_possessions(self, number):
        self.off_possessions += number
    
    def add_def_possessions(self, number):
        self.def_possessions += number
    
    def get_offensive_rating(self):
        return self.points_scored / self.off_possessions * 100 if self.off_possessions != 0 else 0
    
    def get_defensive_rating(self):
        return self.points_allowed / self.def_possessions * 100 if self.def_possessions != 0 else 0

# %% [markdown]
# # Testing out Class functions with one game

# %%
test_game_id = "006728e4c10e957011e1f24878e6054a"

# %%
test_play_by_play = play_by_play[play_by_play['Game_id'] == test_game_id].copy()
test_play_by_play.head()
# Out:
#                             Game_id  Event_Num  Event_Msg_Type  Period  \
# 0  006728e4c10e957011e1f24878e6054a          2              12       1
# 1  006728e4c10e957011e1f24878e6054a          4              10       1
# 2  006728e4c10e957011e1f24878e6054a          7               1       1
# 3  006728e4c10e957011e1f24878e6054a          8               6       1
# 4  006728e4c10e957011e1f24878e6054a         10               3       1
#
#    WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 0   546410     7200            0        0        0        0
# 1   546420     7200            0        0        0        0
# 2   546590     7020           79        2        0        0
# 3   546620     7020            2        0        0        1
# 4   546810     7020           10        1        0        0
#
#                             Team_id                           Person1  \
# 0  1473d70e5646a26de3c52aa1abd85b1f  0370a0d090da0d0edc6319f120187e0e
# 1  01be0ad4af7aeb1f6d2cc2b6b6d6d811  8d2127290c94bd41b82a2938734bc750
# 2  01be0ad4af7aeb1f6d2cc2b6b6d6d811  42e0d7167f04a4ff958c6442da0e6851
# 3  01be0ad4af7aeb1f6d2cc2b6b6d6d811  616281dee946056b071699476fdee9ec
# 4  01be0ad4af7aeb1f6d2cc2b6b6d6d811  42e0d7167f04a4ff958c6442da0e6851
#
#                             Person2                           Person3  \
# 0  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 1  99104de2626f67c1fa2ce70504970c3f  766802a8fda500d7945950de7398c9c6
# 2  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 3  42e0d7167f04a4ff958c6442da0e6851  0b1c631effab25d4af2d16fc123c3d31
# 4  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#    Team_id_type  Person1_type  Person2_type  Person3_type
# 0             0             0             0             0
# 1             2             4             5             4
# 2             2             4             0             0
# 3             2             5             4             1
# 4             2             4             0             0

# %%
test_game_lineup = game_lineup[game_lineup['Game_id'] == test_game_id].copy()
test_game_lineup.head()
# Out:
#                             Game_id  Period                         Person_id  \
# 0  006728e4c10e957011e1f24878e6054a       0  ae53f8ba6761b64a174051da817785bc
# 1  006728e4c10e957011e1f24878e6054a       0  44230324724c84f122ac62a5f0918314
# 2  006728e4c10e957011e1f24878e6054a       0  8d2127290c94bd41b82a2938734bc750
# 3  006728e4c10e957011e1f24878e6054a       0  48ec4e6c52f418d5ca4ef510ba473ea0
# 4  006728e4c10e957011e1f24878e6054a       0  e816ff284dc3f965b8f3d605a3b91bae
#
#                             Team_id status
# 0  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 1  45ba8fc87f55b1191c50c400dc7ed11c      A
# 2  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 3  45ba8fc87f55b1191c50c400dc7ed11c      A
# 4  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A

# %%
test_game = Game(test_game_id, test_play_by_play, test_game_lineup)

# %%
print(test_game)
# Out:
# Game ID:	006728e4c10e957011e1f24878e6054a
#
# 	Team A ID:	01be0ad4af7aeb1f6d2cc2b6b6d6d811
# 	Team B ID:	45ba8fc87f55b1191c50c400dc7ed11c

# %%
print(test_game.team_B)
# Out:
# Team ID:	45ba8fc87f55b1191c50c400dc7ed11c
#
# 	Player 1:	44230324724c84f122ac62a5f0918314
# 	Player 2:	48ec4e6c52f418d5ca4ef510ba473ea0
# 	Player 3:	616281dee946056b071699476fdee9ec
# 	Player 4:	e814950408915f43de2b079dce7c21c5
# 	Player 5:	99104de2626f67c1fa2ce70504970c3f
# 	Player 6:	1b37fed4823f31ccbf03515f4b9fe438
# 	Player 7:	d00d552bc4e50f63f9397a74514519ba
# 	Player 8:	4ef3dae16c436459ff05156abca5cebd
# 	Player 9:	902362537ff2a39c0c0cfb82ab0adac2
# 	Player 10:	4413c19cf092bda39332d7833c90bfe6
# 	Player 11:	bf6ed471f8425903310f08548a206905
# 	Player 12:	5cce6ffa455e6372d9de0de400482ab6
# 	Player 13:	4dd3d6a51dc97c651d3a86eec4362a1f
# 	Player 14:	7027df5d9c51192f3527ac8c74b4d08d
# 	Player 15:	d81d912f81fa43178f423aa89a713e96

# %%
for player in test_game.team_B.roster:
    print(test_game.team_B.roster[player])
# Out:
# Player ID: 44230324724c84f122ac62a5f0918314
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 48ec4e6c52f418d5ca4ef510ba473ea0
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 616281dee946056b071699476fdee9ec
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: e814950408915f43de2b079dce7c21c5
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 99104de2626f67c1fa2ce70504970c3f
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 1b37fed4823f31ccbf03515f4b9fe438
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: d00d552bc4e50f63f9397a74514519ba
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 4ef3dae16c436459ff05156abca5cebd
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 902362537ff2a39c0c0cfb82ab0adac2
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 4413c19cf092bda39332d7833c90bfe6
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: bf6ed471f8425903310f08548a206905
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 5cce6ffa455e6372d9de0de400482ab6
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 4dd3d6a51dc97c651d3a86eec4362a1f
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: 7027df5d9c51192f3527ac8c74b4d08d
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
#
# Player ID: d81d912f81fa43178f423aa89a713e96
# 	Points Scored: 0
# 	Points Allowed: 0
# 	Possessions: 0
# 	Offensive Rating: 0
# 	Defensive Rating: 0
